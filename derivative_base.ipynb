# %%
import pymysql as pydb
pydb.install_as_MySQLdb()
import MySQLdb
from sqlalchemy import create_engine

# %%
user = 'ryuiks'
password = '1q2w3e4r!!'
db_name = 'db_aiam_analysis'

engine = create_engine("mysql+mysqldb://"+user+":"+password+"@10.17.126.105/"+db_name, encoding='utf-8')
conn = engine.connect()

# %%
import pandas as pd

sql = "select * from usetf_basic_data where country='U.S.' "
df = pd.read_sql_query(sql=sql, con=engine)
df.tail()

# conn.close()
# Out:
#     ticker                                               name intro  \
# 591   SDYL    ETRACS Monthly Pay 2xLeveraged S&P Dividend ETN  None
# 592   BDCS  UBS E-TRACS Wells Fargo Business Development C...  None
# 593   MLPG     UBS E-TRACS Alerian Natural Gas MLP Index Fund  None
# 594   MLPI         UBS E-TRACS Alerian MLP Infrastructure ETN  None
# 595    QVM                        Arrow QVM Equity Factor ETF  None
#
#                           issuer brand structure  expense_ratio   inception  \
# 591  UBS Global Asset Management     0       ETN         0.0030  2012-05-22
# 592  UBS Global Asset Management     0       ETN         0.0085  2011-04-27
# 593  UBS Global Asset Management     0       ETN         0.0085  2010-07-13
# 594  UBS Global Asset Management     0       ETN         0.0085  2010-03-31
# 595                  ArrowShares     0       ETF         0.0065  2015-02-27
#
#     tax_form index_ticker  ... asset_class_size asset_class_style  \
# ...

# %%
df.head(3)
# Out:
#   ticker                                    name  \
# 0   UVXY  ProShares Ultra VIX Short-Term Futures
# 1    SPY                        SPDR S&P 500 ETF
# 2    XLF       Financial Select Sector SPDR Fund
#
#                                                intro        issuer      brand  \
# 0  This ETF offers leveraged exposure to an index...     ProShares  ProShares
# 1  SPY is one of the largest and most heavily-tra...  State Street       SPDR
# 2  This ETF, one of the powerhouse SPDR products,...  State Street       SPDR
#
#   structure  expense_ratio   inception tax_form index_ticker  ...  \
# 0       ETF       0.009500  2011-10-04      K-1       SPVXSP  ...
# 1       ETF       0.000945  1993-01-22     1099         SPXT  ...
# 2       ETF       0.001200  1998-12-22     1099        IXMTR  ...
#
#   asset_class_size asset_class_style         region country sector_general  \
# 0             None              None  North America    U.S.           None
# ...

# %%
sql = f"""select a.str_code, a.activate, cal_profit(a.str_code, '2021-07-29', 0) 1d, cal_profit(a.str_code, '2021-07-29', 7) 1w										
,cal_profit(a.str_code, '2021-07-29', 14) 2w, cal_profit(a.str_code, '2021-07-29', 30) 1m										
,cal_profit(a.str_code, '2021-07-29', 91) 3m, cal_profit(a.str_code, '2021-07-29', 182) 6m										
,cal_profit(a.str_code, '2021-07-29', 365) 1y, cal_profit(a.str_code, '2021-07-29', 1000) cum										
,cal_hit(a.str_code, '2021-07-29', 1000) hit, cal_vol(a.str_code, '2021-07-29', 365) vol										
from dm_strategys a, select_return b  where b.date = '2021-07-29' and a.str_code = b.str_code and a.activate > 0;
"""

print(sql)
df = pd.read_sql_query(sql=sql, con=engine)
# Out:
# select a.str_code, a.activate, cal_profit(a.str_code, '2021-07-29', 0) 1d, cal_profit(a.str_code, '2021-07-29', 7) 1w
# ,cal_profit(a.str_code, '2021-07-29', 14) 2w, cal_profit(a.str_code, '2021-07-29', 30) 1m
# ,cal_profit(a.str_code, '2021-07-29', 91) 3m, cal_profit(a.str_code, '2021-07-29', 182) 6m
# ,cal_profit(a.str_code, '2021-07-29', 365) 1y, cal_profit(a.str_code, '2021-07-29', 1000) cum
# ,cal_hit(a.str_code, '2021-07-29', 1000) hit, cal_vol(a.str_code, '2021-07-29', 365) vol
# from dm_strategys a, select_return b  where b.date = '2021-07-29' and a.str_code = b.str_code and a.activate > 0;

# %%
print(df.shape)
df.head(3)
# Out:
# (12, 12)
#    str_code  activate   1d    1w    2w    1m    3m    6m    1y   cum  \
# 0  dm_165_0         2  0.0  0.09 -0.12 -0.24 -0.24 -0.24 -0.24 -0.24
# 1  dm_165_1         2  0.0  0.02 -0.11  0.40  0.40  0.40  0.40  0.40
# 2  dm_165_2         2  0.0  0.02 -0.09  0.40  0.40  0.40  0.40  0.40
#
#         hit   vol
# 0  0.461538  1.27
# 1  0.538462  1.90
# 2  0.538462  1.81

# %%
# df.to_dict()
# print(df.to_html())
